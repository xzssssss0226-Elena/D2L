# %% [markdown]
# #### 1. 训练误差和泛化误差

# %% [markdown]
# ### 2.模型选择

# %% [markdown]
# ### 3. 欠拟合还是过拟合

# %% [markdown]
# ### 4. 多项式回归

# %%
import math
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l
